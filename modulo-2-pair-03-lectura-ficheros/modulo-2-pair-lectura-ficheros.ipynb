# %% [markdown]
# - Pair Lectura de ficheros
# En este pair vamos a trabajar la apertura y exploración de archivos. Para finalmente guardar el archivo con un formato diferente.
#
# Archivo para los ejercicios:

# %% [markdown]
# 1 - Hacer las importaciones necesarias para abrir un archivo de tipo csv en Pandas.
#
# 2- Abrir el archivo, creando un dataframe. Aseguraros de que no incluye la columna "Unnamed: 0".

# %%
import json
import pandas as pd


#index_col=0 → le dice a Pandas que la primera columna del CSV se use como índice, no como dato. Esto evita "Unnamed: 0".
#corroborar que el csv a consultar esté bien escrito

# %%
data_VG = pd.read_csv("videogames.csv", index_col=0)

# %%
pd.DataFrame(data_VG)
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# ...

# %% [markdown]
# 3 - Guardar el dataframe en formato Excel y después crear un dataframe con el Excel.
#  ¿El dataframe es similar al que teníais antes?
#
#   - Lo vemos igual

# %%
#transformar un archivo de CSV a EXCEL to_XX 
#index=False solo para codigo de transformación para visualizar index=0

data_VG.to_excel("modulo-2-pair-lectura-ficheros/videogames.xlsx", index=False)

# %%
#Leer un archivo Read_ XX
df_excel = pd.read_excel("videogames.xlsx")

# %%
pd.DataFrame(df_excel)
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# ...

# %% [markdown]
# 4 -Crear una carpeta llamada Files y guardar el mismo archivo en esa carpeta en formato csv

# %%
import os 

os.getcwd()
# Out:
# 'c:\\Users\\loren\\Downloads\\ADALAB\\MODULO_2\\REPOSITORIOS_MOD_2\\pair_mod2_Ana_Lorena'

# %%
data_VG.to_csv("file_ejercicio_ficheros/videogames.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 data_VG.to_csv(" file_ejercicio_ficheros/videogames.csv",index=False)
#
# File c:\Users\loren\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3977 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3979 formatter = DataFrameFormatter(
#    3980     frame=df,
#    3981     header=header,
#    (...)   3985     decimal=decimal,
#    3986 )
# -> 3988 return DataFrameRenderer(formatter).to_csv(
#    3989     path_or_buf,
#    3990     lineterminator=lineterminator,
#    3991     sep=sep,
# ...
